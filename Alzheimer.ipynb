# %% [markdown]
# ## D2D Example: CLD on Alzheimer's Disease
# In this example, we  implement a diagrams-to-dynamics (D2D) analysis of a causal loop diagram (CLD) published by Uleman et al (2020) doi: 10.1007/s11357-020-00228-7. This CLD was turned into a data-driven system dynamics model (SDM) in Uleman (2023) doi: 10.1002/alz.12923.
#
# In Kumu, the SDM looks as follows:
#
# <img src="Alzheimer CLD.jpg" alt="drawing" width="500"/>
#
# To analyze this CLD, we will first imports the settings and the Kumu file. We will then run the simulations with what-if scenarios, assess the intervention effects, and then perform sensitivity analysis over the model parameters.

# %%
import os
from funcs.cld import Extract
from funcs.d2d import D2D
from funcs.plots import plot_simulated_intervention_ranking

current_path = os.getcwd()  # Select current path
file_name = "Alzheimer"  # Specify the relevant name of the CLD Excel file
file_path = os.path.join(current_path, f"{file_name}.xlsx")

extract = Extract(file_path)  # Load the relevant Kumu file extraction module
s = extract.extract_settings()  # Extract the settings using the Kumu Excel file

# Set simulation settings
s.seed = 1912884
s.N = 200  # Number of simulations
s.t_end = 20  # Timeframe of the simulation
s.time_unit = "Quarter-years"  # Base unit of time (time unit of t_end)
s.parameter_value_aux = 0.3
s.parameter_value_stocks = 0.1

sdm = D2D(s)  # Load the module for formulating and simulating the SDM
# Out:
# Variable of interest: Cognitive functioning
# with 15 intervention variables
# Removed 2.0 incoming link(s) for constant Diabetes
# Removed 4.0 incoming link(s) for constant Dyslipidaemia
# Removed 6.0 incoming link(s) for constant Social relationships
# Removed 1.0 incoming link(s) for constant Hearing loss
# Removed 2.0 incoming link(s) for constant Smoking
# Removed 1.0 incoming link(s) for constant Excessive alcohol use
# Removed 4.0 incoming link(s) for constant Motor function
#
# 75 feedback loops of maximum length 5
# All loops have at least one stock
# No interaction terms specified so will solve linear SDM.

# %%
df_sol, param_samples = sdm.run_simulations()  # Run the simulated interventions
intervention_effects_per_voi = sdm.get_intervention_effects()  # Get the intervention effects
# Out:
# Running 200 D2D simulations with JAX...
# Processing Results: 100%|██████████| 200/200 [00:00<00:00, 588.96it/s]

# %%
for voi in s.variable_of_interest:
    plot_simulated_intervention_ranking(s, intervention_effects_per_voi[voi], 
                                        voi, top_plot=None, order=None);  # Plot the simulated interventions ranking

# %%
from funcs.plots import plot_simulated_interventions_compare

# Interactive plot comparing the simulated interventions for all variables of interest
plot_simulated_interventions_compare(sdm.s, df_sol)
# Out:
# interactive(children=(FloatSlider(value=0.95, description='Interval bounds:', max=0.99, min=0.01, step=0.01), …

# %%
## Intervention effects table
for voi in s.variable_of_interest:
    print("---- Variable of Interest: ", voi)
    sdm.compare_interventions_table(intervention_effects_per_voi[voi])  # Print the table of the simulated interventions
    print("")
# Out:
# ---- Variable of Interest:  Cognitive functioning
#
# Comparison Table (Percentage Greater, 95% CI, Cliff’s Delta):
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Intervention A           | Intervention B                            |   % Greater | 95% CI (% Greater)   |   Cliff's Delta |
# +==========================+===========================================+=============+======================+=================+
# | Sleep quality            | Depressive symptoms                       |        72.5 | [65.5, 79.5]         |            0.45 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Social relationships                      |        75   | [69.0, 81.0]         |            0.5  |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Physical activity                         |        79   | [72.5, 85.0]         |            0.58 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Head trauma                               |        77.5 | [71.5, 82.5]         |            0.55 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Healthy dietary patterns                  |        76   | [70.0, 81.5]         |            0.52 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Hearing loss                              |        91   | [86.5, 94.5]         |            0.82 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Smoking                                   |        90   | [86.0, 93.5]         |            0.8  |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Excessive alcohol use                     |        95   | [91.0, 97.5]         |            0.9  |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Diabetes                                  |        96.5 | [93.5, 98.5]         |            0.93 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Education level                           |        99   | [97.5, 100.0]        |            0.98 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Obesity                                   |       100   | [100.0, 100.0]       |            1    |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Dyslipidaemia                             |       100   | [100.0, 100.0]       |            1    |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Blood pressure                            |        99.5 | [98.5, 100.0]        |            0.99 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Sleep quality            | Engagement in cognitively demanding tasks |       100   | [100.0, 100.0]       |            1    |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Social relationships                      |        55   | [48.5, 62.0]         |            0.1  |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Physical activity                         |        57   | [50.5, 63.0]         |            0.14 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Head trauma                               |        62.5 | [56.0, 69.0]         |            0.25 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Healthy dietary patterns                  |        64   | [57.0, 70.0]         |            0.28 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Hearing loss                              |        87   | [82.0, 91.5]         |            0.74 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Smoking                                   |        81   | [75.5, 86.5]         |            0.62 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Excessive alcohol use                     |        87.5 | [82.0, 92.0]         |            0.75 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Diabetes                                  |        89   | [85.0, 93.0]         |            0.78 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Education level                           |        95.5 | [92.5, 98.0]         |            0.91 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Obesity                                   |        98.5 | [96.5, 100.0]        |            0.97 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Dyslipidaemia                             |        98   | [96.0, 99.5]         |            0.96 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Blood pressure                            |        98.5 | [96.5, 100.0]        |            0.97 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Depressive symptoms      | Engagement in cognitively demanding tasks |       100   | [100.0, 100.0]       |            1    |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Social relationships     | Physical activity                         |        45.5 | [38.5, 51.0]         |           -0.09 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Social relationships     | Head trauma                               |        61.5 | [55.5, 68.0]         |            0.23 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Social relationships     | Healthy dietary patterns                  |        62   | [56.0, 67.5]         |            0.24 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Social relationships     | Hearing loss                              |        83.5 | [78.5, 88.0]         |            0.67 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Social relationships     | Smoking                                   |        80.5 | [75.0, 85.5]         |            0.61 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Social relationships     | Excessive alcohol use                     |        89.5 | [84.5, 93.0]         |            0.79 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Social relationships     | Diabetes                                  |        91   | [87.5, 94.5]         |            0.82 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Social relationships     | Education level                           |        96.5 | [93.5, 98.5]         |            0.93 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Social relationships     | Obesity                                   |        99   | [97.5, 100.0]        |            0.98 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Social relationships     | Dyslipidaemia                             |        99   | [97.5, 100.0]        |            0.98 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Social relationships     | Blood pressure                            |        99.5 | [98.0, 100.0]        |            0.99 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Social relationships     | Engagement in cognitively demanding tasks |       100   | [100.0, 100.0]       |            1    |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Physical activity        | Head trauma                               |        59   | [52.5, 65.5]         |            0.18 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Physical activity        | Healthy dietary patterns                  |        64.5 | [57.0, 71.0]         |            0.29 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Physical activity        | Hearing loss                              |        79   | [74.5, 84.0]         |            0.58 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Physical activity        | Smoking                                   |        80.5 | [75.5, 86.0]         |            0.61 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Physical activity        | Excessive alcohol use                     |        88.5 | [84.0, 92.5]         |            0.77 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Physical activity        | Diabetes                                  |        92.5 | [89.0, 96.0]         |            0.85 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Physical activity        | Education level                           |        98   | [95.5, 99.5]         |            0.96 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Physical activity        | Obesity                                   |       100   | [100.0, 100.0]       |            1    |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Physical activity        | Dyslipidaemia                             |       100   | [100.0, 100.0]       |            1    |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Physical activity        | Blood pressure                            |        99.5 | [98.5, 100.0]        |            0.99 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Physical activity        | Engagement in cognitively demanding tasks |       100   | [100.0, 100.0]       |            1    |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Head trauma              | Healthy dietary patterns                  |        45.5 | [39.0, 52.0]         |           -0.09 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Head trauma              | Hearing loss                              |        69   | [62.0, 75.0]         |            0.38 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Head trauma              | Smoking                                   |        74.5 | [68.5, 81.0]         |            0.49 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Head trauma              | Excessive alcohol use                     |        89   | [84.5, 93.0]         |            0.78 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Head trauma              | Diabetes                                  |        91   | [87.0, 94.5]         |            0.82 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Head trauma              | Education level                           |        89   | [85.0, 93.0]         |            0.78 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Head trauma              | Obesity                                   |        96   | [93.0, 98.0]         |            0.92 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Head trauma              | Dyslipidaemia                             |        98.5 | [96.5, 99.5]         |            0.97 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Head trauma              | Blood pressure                            |       100   | [100.0, 100.0]       |            1    |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Head trauma              | Engagement in cognitively demanding tasks |       100   | [100.0, 100.0]       |            1    |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Healthy dietary patterns | Hearing loss                              |        71.5 | [66.0, 78.0]         |            0.43 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Healthy dietary patterns | Smoking                                   |        77   | [70.0, 83.0]         |            0.54 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Healthy dietary patterns | Excessive alcohol use                     |        85.5 | [80.5, 90.0]         |            0.71 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Healthy dietary patterns | Diabetes                                  |        92.5 | [89.0, 95.5]         |            0.85 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Healthy dietary patterns | Education level                           |        92   | [88.0, 95.0]         |            0.84 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Healthy dietary patterns | Obesity                                   |        98.5 | [96.5, 99.5]         |            0.97 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Healthy dietary patterns | Dyslipidaemia                             |        99   | [97.5, 100.0]        |            0.98 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Healthy dietary patterns | Blood pressure                            |       100   | [100.0, 100.0]       |            1    |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Healthy dietary patterns | Engagement in cognitively demanding tasks |       100   | [100.0, 100.0]       |            1    |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Hearing loss             | Smoking                                   |        45.5 | [38.5, 52.0]         |           -0.09 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Hearing loss             | Excessive alcohol use                     |        55   | [48.0, 62.5]         |            0.1  |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Hearing loss             | Diabetes                                  |        61   | [53.0, 67.0]         |            0.22 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Hearing loss             | Education level                           |        66.5 | [59.0, 73.0]         |            0.33 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Hearing loss             | Obesity                                   |        81   | [76.0, 86.0]         |            0.62 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Hearing loss             | Dyslipidaemia                             |        85.5 | [80.5, 90.0]         |            0.71 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Hearing loss             | Blood pressure                            |        83.5 | [79.0, 89.0]         |            0.67 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Hearing loss             | Engagement in cognitively demanding tasks |        95   | [92.0, 98.0]         |            0.9  |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Smoking                  | Excessive alcohol use                     |        63.5 | [57.0, 69.5]         |            0.27 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Smoking                  | Diabetes                                  |        75.5 | [69.0, 81.5]         |            0.51 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Smoking                  | Education level                           |        76.5 | [69.5, 82.0]         |            0.53 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Smoking                  | Obesity                                   |        89   | [84.5, 93.0]         |            0.78 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Smoking                  | Dyslipidaemia                             |        96   | [92.5, 98.0]         |            0.92 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Smoking                  | Blood pressure                            |        95   | [92.5, 97.5]         |            0.9  |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Smoking                  | Engagement in cognitively demanding tasks |        98   | [96.0, 99.5]         |            0.96 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Excessive alcohol use    | Diabetes                                  |        54.5 | [48.0, 61.5]         |            0.09 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Excessive alcohol use    | Education level                           |        59   | [52.0, 65.0]         |            0.18 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Excessive alcohol use    | Obesity                                   |        78   | [72.5, 83.5]         |            0.56 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Excessive alcohol use    | Dyslipidaemia                             |        84   | [79.0, 88.5]         |            0.68 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Excessive alcohol use    | Blood pressure                            |        87   | [82.5, 91.5]         |            0.74 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Excessive alcohol use    | Engagement in cognitively demanding tasks |        95.5 | [93.0, 98.0]         |            0.91 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Diabetes                 | Education level                           |        58.5 | [51.5, 65.0]         |            0.17 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Diabetes                 | Obesity                                   |        79.5 | [75.0, 85.5]         |            0.59 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Diabetes                 | Dyslipidaemia                             |        88   | [82.0, 92.0]         |            0.76 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Diabetes                 | Blood pressure                            |        89   | [84.0, 93.0]         |            0.78 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Diabetes                 | Engagement in cognitively demanding tasks |        94.5 | [91.5, 97.5]         |            0.89 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Education level          | Obesity                                   |        80   | [74.5, 85.5]         |            0.6  |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Education level          | Dyslipidaemia                             |        87.5 | [84.0, 91.5]         |            0.75 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Education level          | Blood pressure                            |        84.5 | [79.5, 88.5]         |            0.69 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Education level          | Engagement in cognitively demanding tasks |        99.5 | [98.5, 100.0]        |            0.99 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Obesity                  | Dyslipidaemia                             |        59.5 | [52.0, 66.0]         |            0.19 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Obesity                  | Blood pressure                            |        69   | [63.0, 74.5]         |            0.38 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Obesity                  | Engagement in cognitively demanding tasks |        87   | [81.5, 91.5]         |            0.74 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Dyslipidaemia            | Blood pressure                            |        54   | [47.5, 61.5]         |            0.08 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Dyslipidaemia            | Engagement in cognitively demanding tasks |        75.5 | [68.5, 81.0]         |            0.51 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+
# | Blood pressure           | Engagement in cognitively demanding tasks |        74.5 | [68.5, 80.0]         |            0.49 |
# +--------------------------+-------------------------------------------+-------------+----------------------+-----------------+

# %% [markdown]
# ## Sensitivity analysis

# %%
## Estimate spearman correlation for the model parameters, either for one intervention variable (int_var) or for all
cut_off_SA_importance = 0.1
int_var = None  # If None, the simulations of all intervention will be used

for voi in s.variable_of_interest:
    print("---- Variable of Interest: ", voi)
    outcome_var = voi  # If None, all variables will be used to assess change in the model
    SA_results, df_SA = sdm.run_SA(outcome_var, int_var, cut_off_SA_importance)
    print("")
# Out:
# ---- Variable of Interest:  Cognitive functioning
# +---------------------------------------------------+-------+--------------------+------------------+----------------+
# |                       Link                        |  Rho  | 95% CI (bootstrap) | Mean Rho per Int | SD Rho per Int |
# +---------------------------------------------------+-------+--------------------+------------------+----------------+
# |    Neuronal dysfunction->Cognitive functioning    | -0.31 |   [-0.34, -0.28]   |      -0.45       |      0.19      |
# |    Depressive symptoms->Cognitive functioning     | -0.19 |   [-0.22, -0.16]   |      -0.29       |      0.21      |
# |   Head trauma->Cerebral endothelial dysfunction   | 0.12  |    [0.08, 0.16]    |       0.17       |      0.08      |
# |    Cognitive functioning->Depressive symptoms     | -0.11 |   [-0.14, -0.08]   |      -0.16       |      0.05      |
# |      Physical activity->Depressive symptoms       | -0.1  |   [-0.13, -0.07]   |      -0.16       |      0.12      |
# | Cerebral endothelial dysfunction->Brain perfusion | -0.1  |   [-0.13, -0.07]   |      -0.15       |      0.06      |
# +---------------------------------------------------+-------+--------------------+------------------+----------------+

# %% [markdown]
# ## Additional figures

# %%
datadriven_ranking = ["Sleep quality", "Depressive symptoms", "Hearing loss", "Head trauma", 
                      "Healthy dietary patterns", "Smoking", "Excessive alcohol use", 
                      "Social relationships", "Education level", "Physical activity", 
                      "Diabetes", "Obesity", "Blood pressure", "Dyslipidaemia", 
                      "Engagement in cognitively demanding tasks"]

plot_simulated_intervention_ranking(s, intervention_effects_per_voi[voi], voi,
                                    top_plot=None, order=datadriven_ranking);

# %%
## Centrality plot for comparison
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

def plot_centrality(s, datadriven_ranking):
    """ Plot the betweenness and closeness centrality rankings of the system for comparison purposes.
    """
    datadriven_ranking = [" ".join(x.split('_')) for x in datadriven_ranking]

    # Create a DataFrame
    centrality_df = pd.DataFrame(s.centrality)
    centrality_df["Factor"] = centrality_df.index

    # Filter for the selected 15 factors
    centrality_df = centrality_df[centrality_df["Factor"].isin([var.replace('_', ' ') for var in s.intervention_variables])]

    # Sort DataFrames by centrality values
    df_betweenness = centrality_df.sort_values(by="betweenness", ascending=False)
    df_closeness = centrality_df.sort_values(by="closeness", ascending=False)

    # Plot
    fig, axes = plt.subplots(1, 2, figsize=(14, 10), sharex=False)
    #fig, axes = plt.subplots(1, 1, figsize=(7, 10), sharex=True)
    sns.barplot(data=df_betweenness.loc[datadriven_ranking, :], y="Factor", x="betweenness", ax=axes[0], color='darkseagreen')
    axes[0].set_title("Betweenness Centrality")
    axes[0].set_xlabel("Centrality Value")
    axes[0].set_ylabel("Factor")

    sns.barplot(data=df_closeness.loc[datadriven_ranking, :], y="Factor", x="closeness", ax=axes[1], color='lightslategray')
    axes[1].set_title("Closeness Centrality")
    axes[1].set_xlabel("Centrality Value")
    axes[1].set_ylabel("")  # Remove y-axis label to avoid redundancy

    plt.tight_layout()
    plt.show()

plot_centrality(s, datadriven_ranking)

# %%
df_intervention_effects = pd.DataFrame(intervention_effects_per_voi[voi], columns=s.intervention_variables)

# Add centrality and data-driven rankings
df_intervention_effects.loc['Closeness'] = [s.centrality['closeness'].get(var, 0) for var in df_intervention_effects.columns]
df_intervention_effects.loc['Betweenness'] = [s.centrality['betweenness'].get(var, 0) for var in df_intervention_effects.columns]
df_intervention_effects.loc['Data-driven'] = [len(datadriven_ranking) - datadriven_ranking.index(var) if var in datadriven_ranking else 0 for var in df_intervention_effects.columns]

# Calculate correlations
median_values = df_intervention_effects.loc[0:199].median()
datadriven_values = df_intervention_effects.loc["Data-driven"]
closeness_values = df_intervention_effects.loc["Closeness"]
betweenness_values = df_intervention_effects.loc["Betweenness"]

print(f"Correlation Data-driven SDM and D2D: {median_values.corr(datadriven_values, method='spearman'):.2f}")
print(f"Correlation Data-driven SDM and Closeness: {datadriven_values.corr(closeness_values, method='spearman'):.2f}")
print(f"Correlation Data-driven SDM and Betweenness: {datadriven_values.corr(betweenness_values, method='spearman'):.2f}")
# Out:
# Correlation Data-driven SDM and D2D: 0.83
# Correlation Data-driven SDM and Closeness: 0.51
# Correlation Data-driven SDM and Betweenness: 0.11
